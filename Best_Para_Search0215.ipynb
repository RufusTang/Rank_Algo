# %%
import numpy as np
from matplotlib import cm, pyplot as plt
import matplotlib.dates as dates
import pandas as pd
from datetime import timedelta,date

import sklearn

import warnings
warnings.filterwarnings("ignore")

import time

import pickle

from six import StringIO    #使用聚宽readfile函数

# %%
para1_close_pd = pd.read_csv("para1_close.csv",index_col = 0)

para1_volume_pd = pd.read_csv("para1_volume.csv",index_col = 0)

para2_pd = pd.read_csv("para2.csv",index_col = 0)

# %%
# 一、组成最基础的价格、成交额数据


################# 基础数据  ###################
# price_data_pd ： 从聚宽平台中提取的基础数据，表示沪深300指数股在时间段内的收盘价、成交额



# 沪深300指数股
# Secs = get_index_stocks('000300.XSHG')


# 存储最佳参数的变量赋初始值
Para_list = []
win_count = 0
total_count = 1
yield_rate = 0

# 二、搜集相应的数据进行数据的组装，生成收益率排名、成交额排名


#################  标准参数  #################
# 回滚观察过去的时间长度，表示以过去多长时间的长度作为观察长度
for n_period in range(2,20,4):

    
    # 每次获胜次数、总次数在每次循环时间归零
    win_count = 0
    total_count = 1
    yield_rate = 0

    print "check_point 0"

    #################### 生成收益率排名  ############
    # 收益率的pandas数组
    # data_yield_rank_pd ：表示以过去n_period为周期的时间段内的收益率排名，每天排名

    # 其中利用到全局参数 n_period
    data_yield_pd = pd.DataFrame()
    data_yield_pd = pd.rolling_sum(np.log(para1_close_pd/para1_close_pd.shift(1)),n_period).shift(1)
    
    # 收益率的每天排序的数组
    # axis = 1：表示横向的数列进行排列
    # axis = 0：表示纵向的数列进行排列
    # 此处应该用1，采用横向的数组进行排列
    data_yield_rank_pd = data_yield_pd.rank(axis = 1)

    # 填充Nan数据为300
    data_yield_rank_pd.fillna(300,inplace = True)
    
    # 删除为Nan的行
    # data_yield_rank_pd = data_yield_rank_pd.dropna(axis=0,how='any')

    #################### 生成成交额排名  ############
    # data_money_rank_pd ：表示以过去n_period为周期的时间段内的成交额排名，每天排名
    data_money_pd = pd.DataFrame()
    data_money_pd = pd.rolling_sum(np.log(para1_volume_pd/para1_volume_pd.shift(1)),n_period).shift(1)

    # 对数据做修补，删除TOP、BOTTOM数据
    # data_money_pd.drop(index = data_money_pd.nlargest(n = 20).index)
    
    # 收益率的每天排序的数组
    # axis = 1：表示横向的数列进行排列
    # axis = 0：表示纵向的数列进行排列
    # 此处应该用1，采用横向的数组进行排列
    data_money_rank_pd = data_money_pd.rank(axis = 1)

    # 填充Nan数据为300
    data_money_rank_pd.fillna(300,inplace = True)

    # 删除为Nan的行
    # data_money_rank_pd = data_money_rank_pd.dropna(axis=0,how='any')
    
    # print "check_point 1"
    
    
    
    #   三、按照co_XX的系数，结合两个排名pandas数组，最终生成打分的pandas数组
    
    # 收益率系数，用于加权
    for co_yield in range(-5,5):
        # 成交额系数，用于加权
        for co_money in range(-5,5):
            #################### 生成score_pd  ############
            # score_pd ： 按照成交额、收益率排名，乘以系数以后打分的得分值
            score_pd = pd.DataFrame()
            score_pd = data_yield_rank_pd*co_yield + data_money_rank_pd*co_money

            # 注意：因为是填充0，所以后面选择最佳组合数量时，推荐使用pd.nlargest(n=XXX)
            score_pd.fillna(0,inplace = True)
                        
        
            # 四、挑选股票，对比自选组合和市场组合的收益率
            #################### 关键参数 ##################
            # 延迟后n_lag天，延迟n_lag天作为最终的收益结算时间
            for n_lag in range(2,20,4):
                #################### 生成市场收益率（注意不是每日）  ############
                # market_yield_pd ：表示延迟n_lag天的收益率，用于与组合收益率进行比较
                market_data_pd = pd.DataFrame()
                
                market_data_pd = para2_pd
                
                # 注意：这里是滚动相加后再移位，移位根据测试需要加1
                market_yield_pd = pd.rolling_sum(np.log(para2_pd/para2_pd.shift(1)),n_lag).shift(-n_lag+1)

                # print "check_point 2"

                #################### 生成市场收益率（注意不是每日）  ############
                # portfolio_yield_pd ：表示延迟n_lag天的收益率，用于与组合收益率进行比较

                # 关键参数
                # 选择股票的数量
                n_length = 30

                # 每日的候选股票列表，结构为{日期：[股票1，股票2，股票3....股票n_length]}
                candidate_secs = {}

                
                
                for k,v in score_pd.iterrows():
                    # 注意：这里剔除了排名前20的最热股票，防止异常数据
                    candidate_secs[k] = list(v.nlargest(n=(n_length+20)).index[20:(n_length+20)])

                # print "check_point 3"

                # 合计所有数据的收益率
                # 相应组合的收益率从总的收益率中产生
                portfolio_yield_total_pd = pd.rolling_sum(np.log(para1_close_pd/para1_close_pd.shift(1)),n_lag).shift(-n_lag+1)


                # 用于暂存每个日期的收益率的字典
                portfolio_yield_dict = {}

                for i in range(0,portfolio_yield_total_pd.shape[0]):
                    portfolio_yield_dict[portfolio_yield_total_pd.index[i]] = sum(portfolio_yield_total_pd.loc[portfolio_yield_total_pd.index[i],candidate_secs[portfolio_yield_total_pd.index[i]]])/len(candidate_secs[portfolio_yield_total_pd.index[i]])
                # print "check_point 4"

                # 生成所需的组合收益率pandas数组
                portfolio_yield_pd = pd.DataFrame.from_dict(portfolio_yield_dict,orient='index')
                portfolio_yield_pd.columns = ['portfolio_yield']
                
                
                # 五、比较市场收益率与组合收益率的情况
                # 生成组合对比的pandas数组
                cmp_pd = pd.DataFrame()
                market_yield_pd.columns = ['market_yield']
                cmp_pd = pd.concat([market_yield_pd,portfolio_yield_pd],axis = 1)
                
                # 删除无效的Nan数据
                cmp_pd = cmp_pd.dropna(axis=0,how='any')

                # 计算portfolio大于market的数量
                win_count = cmp_pd[cmp_pd['portfolio_yield']>cmp_pd['market_yield']].shape[0]

                # 计算总的次数
                total_count = cmp_pd.shape[0]
                
                # 胜过市场的总的收益率
                yield_rate = sum(cmp_pd['portfolio_yield'] - cmp_pd['market_yield'])
                
                # print "找到参数，n_period为%d,co_yield为%d,co_money为%d,n_lag为%d,胜率为%f,收益率为%f"%(n_period,co_yield,co_money,n_lag,float(win_count)/float(total_count),yield_rate)
                
                # 判断是否达到标准条件
                if yield_rate> 0 :
                    if float(win_count)/float(total_count) > 0.6:
                        print "找到最佳参数，n_period为%d,co_yield为%d,co_money为%d,n_lag为%d,胜率为%f,收益率为%f"%(n_period,co_yield,co_money,n_lag,float(win_count)/float(total_count),yield_rate)
                        Para_list.append([n_period,co_yield,co_money,n_lag,win_count,total_count,yield_rate])
# Out:
# check_point 0
# 找到最佳参数，n_period为2,co_yield为-5,co_money为0,n_lag为6,胜率为0.602683,收益率为2.909046
# 找到最佳参数，n_period为2,co_yield为-5,co_money为2,n_lag为6,胜率为0.600619,收益率为2.464679
# 找到最佳参数，n_period为2,co_yield为-5,co_money为3,n_lag为6,胜率为0.608875,收益率为3.410712
# 找到最佳参数，n_period为2,co_yield为-5,co_money为4,n_lag为6,胜率为0.610939,收益率为2.960466
# 找到最佳参数，n_period为2,co_yield为-4,co_money为0,n_lag为6,胜率为0.602683,收益率为2.909046
# 找到最佳参数，n_period为2,co_yield为-4,co_money为2,n_lag为6,胜率为0.608875,收益率为2.926410
# 找到最佳参数，n_period为2,co_yield为-4,co_money为3,n_lag为6,胜率为0.609907,收益率为3.150723
# 找到最佳参数，n_period为2,co_yield为-4,co_money为4,n_lag为18,胜率为0.612330,收益率为5.005195
# 找到最佳参数，n_period为2,co_yield为-3,co_money为0,n_lag为6,胜率为0.602683,收益率为2.909046
# 找到最佳参数，n_period为2,co_yield为-3,co_money为1,n_lag为6,胜率为0.600619,收益率为2.404689
# 找到最佳参数，n_period为2,co_yield为-3,co_money为3,n_lag为18,胜率为0.612330,收益率为5.005195
# 找到最佳参数，n_period为2,co_yield为-3,co_money为4,n_lag为18,胜率为0.624339,收益率为5.668842
# 找到最佳参数，n_period为2,co_yield为-2,co_money为0,n_lag为6,胜率为0.602683,收益率为2.909046
# 找到最佳参数，n_period为2,co_yield为-2,co_money为1,n_lag为6,胜率为0.608875,收益率为2.926410
# 找到最佳参数，n_period为2,co_yield为-2,co_money为2,n_lag为18,胜率为0.612330,收益率为5.005195
# 找到最佳参数，n_period为2,co_yield为-2,co_money为3,n_lag为18,胜率为0.613750,收益率为4.950452
# 找到最佳参数，n_period为2,co_yield为-1,co_money为0,n_lag为6,胜率为0.602683,收益率为2.909046
# 找到最佳参数，n_period为2,co_yield为-1,co_money为1,n_lag为18,胜率为0.612330,收益率为5.005195
# 找到最佳参数，n_period为2,co_yield为-1,co_money为3,n_lag为18,胜率为0.700000,收益率为0.543502
# 找到最佳参数，n_period为2,co_yield为-1,co_money为4,n_lag为6,胜率为0.875000,收益率为0.365857
# 找到最佳参数，n_period为2,co_yield为-1,co_money为4,n_lag为10,胜率为0.857143,收益率为0.528465
# 找到最佳参数，n_period为2,co_yield为-1,co_money为4,n_lag为14,胜率为0.857143,收益率为0.573258
# 找到最佳参数，n_period为2,co_yield为-1,co_money为4,n_lag为18,胜率为0.857143,收益率为0.578514
# 找到最佳参数，n_period为2,co_yield为0,co_money为0,n_lag为2,胜率为1.000000,收益率为0.036118
# 找到最佳参数，n_period为2,co_yield为3,co_money为-1,n_lag为2,胜率为1.000000,收益率为0.003794
# 找到最佳参数，n_period为2,co_yield为3,co_money为-1,n_lag为18,胜率为1.000000,收益率为0.017379
# 找到最佳参数，n_period为2,co_yield为4,co_money为-1,n_lag为18,胜率为0.608696,收益率为0.303649
# check_point 0
# 找到最佳参数，n_period为6,co_yield为-3,co_money为-5,n_lag为6,胜率为0.601036,收益率为1.532097
# 找到最佳参数，n_period为6,co_yield为-3,co_money为4,n_lag为6,胜率为0.616822,收益率为4.043465
# 找到最佳参数，n_period为6,co_yield为-3,co_money为4,n_lag为10,胜率为0.608968,收益率为5.368959
# 找到最佳参数，n_period为6,co_yield为-3,co_money为4,n_lag为14,胜率为0.611518,收益率为6.745689
# 找到最佳参数，n_period为6,co_yield为-3,co_money为4,n_lag为18,胜率为0.625657,收益率为8.173080
# 找到最佳参数，n_period为6,co_yield为-2,co_money为3,n_lag为6,胜率为0.600902,收益率为3.841341
# 找到最佳参数，n_period为6,co_yield为-2,co_money为3,n_lag为10,胜率为0.604757,收益率为4.908647
# 找到最佳参数，n_period为6,co_yield为-2,co_money为3,n_lag为14,胜率为0.614334,收益率为6.020725
# 找到最佳参数，n_period为6,co_yield为-2,co_money为3,n_lag为18,胜率为0.611429,收益率为7.336554
# 找到最佳参数，n_period为6,co_yield为-1,co_money为3,n_lag为2,胜率为0.636364,收益率为0.173608
# 找到最佳参数，n_period为6,co_yield为-1,co_money为3,n_lag为6,胜率为0.909091,收益率为0.647983
# 找到最佳参数，n_period为6,co_yield为-1,co_money为3,n_lag为10,胜率为0.909091,收益率为0.934675
# 找到最佳参数，n_period为6,co_yield为-1,co_money为3,n_lag为14,胜率为1.000000,收益率为0.977191
# 找到最佳参数，n_period为6,co_yield为-1,co_money为3,n_lag为18,胜率为1.000000,收益率为0.927606
# 找到最佳参数，n_period为6,co_yield为-1,co_money为4,n_lag为2,胜率为0.636364,收益率为0.172900
# 找到最佳参数，n_period为6,co_yield为-1,co_money为4,n_lag为6,胜率为0.909091,收益率为0.663567
# 找到最佳参数，n_period为6,co_yield为-1,co_money为4,n_lag为10,胜率为1.000000,收益率为0.963550
# 找到最佳参数，n_period为6,co_yield为-1,co_money为4,n_lag为14,胜率为1.000000,收益率为0.936221
# 找到最佳参数，n_period为6,co_yield为-1,co_money为4,n_lag为18,胜率为1.000000,收益率为0.918841
# 找到最佳参数，n_period为6,co_yield为0,co_money为0,n_lag为2,胜率为1.000000,收益率为0.036118
# 找到最佳参数，n_period为6,co_yield为2,co_money为-1,n_lag为10,胜率为0.609756,收益率为0.323873
# 找到最佳参数，n_period为6,co_yield为3,co_money为-1,n_lag为2,胜率为1.000000,收益率为0.001000
# 找到最佳参数，n_period为6,co_yield为4,co_money为-2,n_lag为10,胜率为0.609756,收益率为0.323873
# check_point 0
# 找到最佳参数，n_period为10,co_yield为-5,co_money为4,n_lag为18,胜率为0.605901,收益率为5.993865
# 找到最佳参数，n_period为10,co_yield为-4,co_money为3,n_lag为18,胜率为0.605901,收益率为6.096742
# 找到最佳参数，n_period为10,co_yield为-4,co_money为4,n_lag为18,胜率为0.614331,收益率为6.365770
# 找到最佳参数，n_period为10,co_yield为-3,co_money为2,n_lag为18,胜率为0.602740,收益率为5.761951
# 找到最佳参数，n_period为10,co_yield为-3,co_money为3,n_lag为18,胜率为0.614331,收益率为6.365770
# 找到最佳参数，n_period为10,co_yield为-3,co_money为4,n_lag为14,胜率为0.610936,收益率为5.572541
# 找到最佳参数，n_period为10,co_yield为-3,co_money为4,n_lag为18,胜率为0.608237,收益率为7.223678
# 找到最佳参数，n_period为10,co_yield为-2,co_money为2,n_lag为18,胜率为0.614331,收益率为6.365770
# 找到最佳参数，n_period为10,co_yield为-2,co_money为3,n_lag为10,胜率为0.601099,收益率为5.329137
# 找到最佳参数，n_period为10,co_yield为-2,co_money为3,n_lag为14,胜率为0.609272,收益率为6.760511
# 找到最佳参数，n_period为10,co_yield为-2,co_money为3,n_lag为18,胜率为0.609756,收益率为8.059206
# 找到最佳参数，n_period为10,co_yield为-2,co_money为4,n_lag为10,胜率为0.605128,收益率为1.739541
# 找到最佳参数，n_period为10,co_yield为-2,co_money为4,n_lag为14,胜率为0.609375,收益率为2.253603
# 找到最佳参数，n_period为10,co_yield为-1,co_money为1,n_lag为18,胜率为0.614331,收益率为6.365770
# 找到最佳参数，n_period为10,co_yield为-1,co_money为2,n_lag为10,胜率为0.605128,收益率为1.739541
# 找到最佳参数，n_period为10,co_yield为-1,co_money为2,n_lag为14,胜率为0.609375,收益率为2.253603
# 找到最佳参数，n_period为10,co_yield为-1,co_money为3,n_lag为2,胜率为0.764706,收益率为0.287184
# 找到最佳参数，n_period为10,co_yield为-1,co_money为3,n_lag为6,胜率为0.823529,收益率为0.907501
# 找到最佳参数，n_period为10,co_yield为-1,co_money为3,n_lag为10,胜率为0.882353,收益率为1.065607
# 找到最佳参数，n_period为10,co_yield为-1,co_money为3,n_lag为14,胜率为0.941176,收益率为1.053089
# 找到最佳参数，n_period为10,co_yield为-1,co_money为3,n_lag为18,胜率为0.941176,收益率为1.292045
# 找到最佳参数，n_period为10,co_yield为-1,co_money为4,n_lag为2,胜率为0.800000,收益率为0.311245
# 找到最佳参数，n_period为10,co_yield为-1,co_money为4,n_lag为6,胜率为0.933333,收益率为0.965702
# 找到最佳参数，n_period为10,co_yield为-1,co_money为4,n_lag为10,胜率为0.866667,收益率为1.012018
# 找到最佳参数，n_period为10,co_yield为-1,co_money为4,n_lag为14,胜率为0.933333,收益率为1.000703
# 找到最佳参数，n_period为10,co_yield为-1,co_money为4,n_lag为18,胜率为0.933333,收益率为1.144959
# 找到最佳参数，n_period为10,co_yield为0,co_money为0,n_lag为2,胜率为1.000000,收益率为0.036118
# 找到最佳参数，n_period为10,co_yield为2,co_money为-1,n_lag为14,胜率为0.633987,收益率为0.888933
# 找到最佳参数，n_period为10,co_yield为2,co_money为-1,n_lag为18,胜率为0.617450,收益率为0.793193
# 找到最佳参数，n_period为10,co_yield为4,co_money为-2,n_lag为14,胜率为0.633987,收益率为0.888933
# 找到最佳参数，n_period为10,co_yield为4,co_money为-2,n_lag为18,胜率为0.617450,收益率为0.793193
# check_point 0
# 找到最佳参数，n_period为14,co_yield为-3,co_money为4,n_lag为10,胜率为0.603358,收益率为4.923977
# 找到最佳参数，n_period为14,co_yield为-3,co_money为4,n_lag为14,胜率为0.610116,收益率为6.412707
# 找到最佳参数，n_period为14,co_yield为-3,co_money为4,n_lag为18,胜率为0.625397,收益率为7.733626
# 找到最佳参数，n_period为14,co_yield为-2,co_money为3,n_lag为14,胜率为0.618002,收益率为5.838999
# 找到最佳参数，n_period为14,co_yield为-2,co_money为3,n_lag为18,胜率为0.601985,收益率为6.565169
# 找到最佳参数，n_period为14,co_yield为-1,co_money为3,n_lag为2,胜率为0.782609,收益率为0.436584
# 找到最佳参数，n_period为14,co_yield为-1,co_money为3,n_lag为6,胜率为0.782609,收益率为1.060567
# 找到最佳参数，n_period为14,co_yield为-1,co_money为3,n_lag为10,胜率为0.782609,收益率为1.161504
# 找到最佳参数，n_period为14,co_yield为-1,co_money为3,n_lag为14,胜率为0.913043,收益率为1.349174
# 找到最佳参数，n_period为14,co_yield为-1,co_money为3,n_lag为18,胜率为1.000000,收益率为1.746395
# 找到最佳参数，n_period为14,co_yield为-1,co_money为4,n_lag为2,胜率为0.772727,收益率为0.417316
# 找到最佳参数，n_period为14,co_yield为-1,co_money为4,n_lag为6,胜率为0.772727,收益率为0.993456
# 找到最佳参数，n_period为14,co_yield为-1,co_money为4,n_lag为10,胜率为0.772727,收益率为1.100580
# 找到最佳参数，n_period为14,co_yield为-1,co_money为4,n_lag为14,胜率为0.909091,收益率为1.266535
# 找到最佳参数，n_period为14,co_yield为-1,co_money为4,n_lag为18,胜率为1.000000,收益率为1.634757
# 找到最佳参数，n_period为14,co_yield为0,co_money为0,n_lag为2,胜率为1.000000,收益率为0.036118
# 找到最佳参数，n_period为14,co_yield为4,co_money为-1,n_lag为18,胜率为0.708333,收益率为0.102711
# check_point 0
# 找到最佳参数，n_period为18,co_yield为-5,co_money为4,n_lag为18,胜率为0.600425,收益率为7.926640
# 找到最佳参数，n_period为18,co_yield为-3,co_money为4,n_lag为14,胜率为0.611640,收益率为6.710236
# 找到最佳参数，n_period为18,co_yield为-2,co_money为3,n_lag为10,胜率为0.600432,收益率为5.440809
# 找到最佳参数，n_period为18,co_yield为-2,co_money为3,n_lag为14,胜率为0.605206,收益率为6.615705
# 找到最佳参数，n_period为18,co_yield为-2,co_money为4,n_lag为6,胜率为0.604502,收益率为2.335404
# 找到最佳参数，n_period为18,co_yield为-1,co_money为2,n_lag为6,胜率为0.604502,收益率为2.335404
# 找到最佳参数，n_period为18,co_yield为-1,co_money为3,n_lag为2,胜率为0.660377,收益率为0.646844
# 找到最佳参数，n_period为18,co_yield为-1,co_money为3,n_lag为6,胜率为0.679245,收益率为1.172759
# 找到最佳参数，n_period为18,co_yield为-1,co_money为3,n_lag为10,胜率为0.754717,收益率为1.883662
# 找到最佳参数，n_period为18,co_yield为-1,co_money为3,n_lag为14,胜率为0.849057,收益率为2.414824
# 找到最佳参数，n_period为18,co_yield为-1,co_money为3,n_lag为18,胜率为0.849057,收益率为2.775630
# 找到最佳参数，n_period为18,co_yield为-1,co_money为4,n_lag为2,胜率为0.673913,收益率为0.619702
# 找到最佳参数，n_period为18,co_yield为-1,co_money为4,n_lag为6,胜率为0.695652,收益率为1.101648
# 找到最佳参数，n_period为18,co_yield为-1,co_money为4,n_lag为10,胜率为0.760870,收益率为1.720833
# 找到最佳参数，n_period为18,co_yield为-1,co_money为4,n_lag为14,胜率为0.913043,收益率为2.413057
# 找到最佳参数，n_period为18,co_yield为-1,co_money为4,n_lag为18,胜率为0.891304,收益率为2.662210
# 找到最佳参数，n_period为18,co_yield为0,co_money为0,n_lag为2,胜率为1.000000,收益率为0.036118
# 找到最佳参数，n_period为18,co_yield为2,co_money为-1,n_lag为10,胜率为0.613636,收益率为0.891402
# 找到最佳参数，n_period为18,co_yield为2,co_money为-1,n_lag为14,胜率为0.601156,收益率为1.039394
# 找到最佳参数，n_period为18,co_yield为4,co_money为-2,n_lag为10,胜率为0.613636,收益率为0.891402
# 找到最佳参数，n_period为18,co_yield为4,co_money为-2,n_lag为14,胜率为0.601156,收益率为1.039394

# %%
para_best = pd.DataFrame(Para_list)
para_best.to_csv("best_para.csv")

# %% [markdown]
# 从聚宽平台导出所需数据，并通过pickle模块另存为文件

# %%
# 模拟开始时间、结束时间
beginDate = '2014-1-1'
endDate = '2017-12-30'
Secs = get_index_stocks('000300.XSHG')

para1_pd = get_price(Secs, start_date = beginDate, end_date=endDate, frequency='daily', fields=['close','volume'],fq = "pre")


pickle.dump(para1_pd,open("para1.dat", 'wb'))

# %%
para2_pd = get_price('000300.XSHG', start_date = beginDate, end_date=endDate, frequency='daily', fields=['close'],fq = "pre")

pickle.dump(para2_pd,open("para2.dat", 'wb'))
